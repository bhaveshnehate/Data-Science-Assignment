# %% [markdown]
# ##### A cloth manufacturing company is interested to know about the segment or attributes causes high sale. Approach - A decision tree can be built with target variable Sale (we will first convert it in categorical variable) & all other variable will be independent in the analysis.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.tree import DecisionTreeClassifier

# %%
df=pd.read_csv('Company_Data.csv')
df
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0     9.50        138      73           11         276    120       Bad   42
# 1    11.22        111      48           16         260     83      Good   65
# 2    10.06        113      35           10         269     80    Medium   59
# 3     7.40        117     100            4         466     97    Medium   55
# 4     4.15        141      64            3         340    128       Bad   38
# ..     ...        ...     ...          ...         ...    ...       ...  ...
# 395  12.57        138     108           17         203    128      Good   33
# 396   6.14        139      23            3          37    120    Medium   55
# 397   7.41        162      26           12         368    159    Medium   40
# 398   5.94        100      79            7         284     95       Bad   50
# 399   9.71        134      37            0          27    120      Good   49
#
#      Education Urban   US
# 0           17   Yes  Yes
# 1           10   Yes  Yes
# 2           12   Yes  Yes
# 3           14   Yes  Yes
# 4           13   Yes   No
# ..         ...   ...  ...
# 395         14   Yes  Yes
# 396         11    No  Yes
# 397         18   Yes  Yes
# 398         12   Yes  Yes
# 399         16   Yes  Yes
#
# [400 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sales        400 non-null    float64
#  1   CompPrice    400 non-null    int64
#  2   Income       400 non-null    int64
#  3   Advertising  400 non-null    int64
#  4   Population   400 non-null    int64
#  5   Price        400 non-null    int64
#  6   ShelveLoc    400 non-null    object
#  7   Age          400 non-null    int64
#  8   Education    400 non-null    int64
#  9   Urban        400 non-null    object
#  10  US           400 non-null    object
# dtypes: float64(1), int64(7), object(3)
# memory usage: 34.5+ KB

# %%
df.describe()
# Out:
#             Sales   CompPrice      Income  Advertising  Population  \
# count  400.000000  400.000000  400.000000   400.000000  400.000000
# mean     7.496325  124.975000   68.657500     6.635000  264.840000
# std      2.824115   15.334512   27.986037     6.650364  147.376436
# min      0.000000   77.000000   21.000000     0.000000   10.000000
# 25%      5.390000  115.000000   42.750000     0.000000  139.000000
# 50%      7.490000  125.000000   69.000000     5.000000  272.000000
# 75%      9.320000  135.000000   91.000000    12.000000  398.500000
# max     16.270000  175.000000  120.000000    29.000000  509.000000
#
#             Price         Age   Education
# count  400.000000  400.000000  400.000000
# mean   115.795000   53.322500   13.900000
# std     23.676664   16.200297    2.620528
# min     24.000000   25.000000   10.000000
# 25%    100.000000   39.750000   12.000000
# 50%    117.000000   54.500000   14.000000
# 75%    131.000000   66.000000   16.000000
# max    191.000000   80.000000   18.000000

# %%
df.isna().sum()
# Out:
# Sales          0
# CompPrice      0
# Income         0
# Advertising    0
# Population     0
# Price          0
# ShelveLoc      0
# Age            0
# Education      0
# Urban          0
# US             0
# dtype: int64

# %%
df.hist()
plt.tight_layout()

# %%
df.corr()
# Out:
#                 Sales  CompPrice    Income  Advertising  Population     Price  \
# Sales        1.000000   0.064079  0.151951     0.269507    0.050471 -0.444951
# CompPrice    0.064079   1.000000 -0.080653    -0.024199   -0.094707  0.584848
# Income       0.151951  -0.080653  1.000000     0.058995   -0.007877 -0.056698
# Advertising  0.269507  -0.024199  0.058995     1.000000    0.265652  0.044537
# Population   0.050471  -0.094707 -0.007877     0.265652    1.000000 -0.012144
# Price       -0.444951   0.584848 -0.056698     0.044537   -0.012144  1.000000
# Age         -0.231815  -0.100239 -0.004670    -0.004557   -0.042663 -0.102177
# Education   -0.051955   0.025197 -0.056855    -0.033594   -0.106378  0.011747
#
#                   Age  Education
# Sales       -0.231815  -0.051955
# CompPrice   -0.100239   0.025197
# Income      -0.004670  -0.056855
# Advertising -0.004557  -0.033594
# Population  -0.042663  -0.106378
# Price       -0.102177   0.011747
# Age          1.000000   0.006488
# Education    0.006488   1.000000

# %%
from sklearn.preprocessing import LabelEncoder,OrdinalEncoder

# %%
oe=OrdinalEncoder()
col_sel=df.select_dtypes(include='object').columns
df[col_sel]=oe.fit_transform(df[col_sel])
df
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age  \
# 0     9.50        138      73           11         276    120        0.0   42
# 1    11.22        111      48           16         260     83        1.0   65
# 2    10.06        113      35           10         269     80        2.0   59
# 3     7.40        117     100            4         466     97        2.0   55
# 4     4.15        141      64            3         340    128        0.0   38
# ..     ...        ...     ...          ...         ...    ...        ...  ...
# 395  12.57        138     108           17         203    128        1.0   33
# 396   6.14        139      23            3          37    120        2.0   55
# 397   7.41        162      26           12         368    159        2.0   40
# 398   5.94        100      79            7         284     95        0.0   50
# 399   9.71        134      37            0          27    120        1.0   49
#
#      Education  Urban   US
# 0           17    1.0  1.0
# 1           10    1.0  1.0
# 2           12    1.0  1.0
# 3           14    1.0  1.0
# 4           13    1.0  0.0
# ..         ...    ...  ...
# 395         14    1.0  1.0
# 396         11    0.0  1.0
# 397         18    1.0  1.0
# 398         12    1.0  1.0
# 399         16    1.0  1.0
#
# [400 rows x 11 columns]

# %%
# oe=OrdinalEncoder()
# col_sel=df.select_dtypes(include='object')
# oe_col=oe.fit_transform(col_sel)
# oe_col=pd.DataFrame(oe_col)
# oe_col

# %%
# df['ShelveLoc']=oe_col[0]
# df['Urban']=oe_col[1]
# df['US']=oe_col[2]
# df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sales        400 non-null    float64
#  1   CompPrice    400 non-null    int64
#  2   Income       400 non-null    int64
#  3   Advertising  400 non-null    int64
#  4   Population   400 non-null    int64
#  5   Price        400 non-null    int64
#  6   ShelveLoc    400 non-null    float64
#  7   Age          400 non-null    int64
#  8   Education    400 non-null    int64
#  9   Urban        400 non-null    float64
#  10  US           400 non-null    float64
# dtypes: float64(4), int64(7)
# memory usage: 34.5 KB

# %% [markdown]
# #### Target column is sale according to problem statem(we will first convert it in categorical variable)

# %%
df.corr()
# Out:
#                 Sales  CompPrice    Income  Advertising  Population     Price  \
# Sales        1.000000   0.064079  0.151951     0.269507    0.050471 -0.444951
# CompPrice    0.064079   1.000000 -0.080653    -0.024199   -0.094707  0.584848
# Income       0.151951  -0.080653  1.000000     0.058995   -0.007877 -0.056698
# Advertising  0.269507  -0.024199  0.058995     1.000000    0.265652  0.044537
# Population   0.050471  -0.094707 -0.007877     0.265652    1.000000 -0.012144
# Price       -0.444951   0.584848 -0.056698     0.044537   -0.012144  1.000000
# ShelveLoc    0.157470   0.023350 -0.067678     0.008544   -0.044772  0.014633
# Age         -0.231815  -0.100239 -0.004670    -0.004557   -0.042663 -0.102177
# Education   -0.051955   0.025197 -0.056855    -0.033594   -0.106378  0.011747
# Urban       -0.015419   0.066594  0.037967     0.042035   -0.052025  0.047016
# US           0.177093   0.016869  0.089601     0.684460    0.060564  0.057861
#
#              ShelveLoc       Age  Education     Urban        US
# Sales         0.157470 -0.231815  -0.051955 -0.015419  0.177093
# CompPrice     0.023350 -0.100239   0.025197  0.066594  0.016869
# Income       -0.067678 -0.004670  -0.056855  0.037967  0.089601
# Advertising   0.008544 -0.004557  -0.033594  0.042035  0.684460
# Population   -0.044772 -0.042663  -0.106378 -0.052025  0.060564
# Price         0.014633 -0.102177   0.011747  0.047016  0.057861
# ShelveLoc     1.000000  0.056488   0.001492 -0.063978 -0.039760
# Age           0.056488  1.000000   0.006488  0.028479  0.008652
# Education     0.001492  0.006488   1.000000 -0.033094 -0.078250
# Urban        -0.063978  0.028479  -0.033094  1.000000  0.047085
# US           -0.039760  0.008652  -0.078250  0.047085  1.000000

# %%
plt.rcParams['figure.figsize']=(10,5)
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
df["sales"]="Bad"
df.loc[df["Sales"]>7.49,"sales"]="Good"
df.drop(["Sales"],axis=1,inplace=True)

# %%
df
# Out:
#      CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age  \
# 0          138      73           11         276    120        0.0   42
# 1          111      48           16         260     83        1.0   65
# 2          113      35           10         269     80        2.0   59
# 3          117     100            4         466     97        2.0   55
# 4          141      64            3         340    128        0.0   38
# ..         ...     ...          ...         ...    ...        ...  ...
# 395        138     108           17         203    128        1.0   33
# 396        139      23            3          37    120        2.0   55
# 397        162      26           12         368    159        2.0   40
# 398        100      79            7         284     95        0.0   50
# 399        134      37            0          27    120        1.0   49
#
#      Education  Urban   US sales
# 0           17    1.0  1.0  Good
# 1           10    1.0  1.0  Good
# 2           12    1.0  1.0  Good
# 3           14    1.0  1.0   Bad
# 4           13    1.0  0.0   Bad
# ..         ...    ...  ...   ...
# 395         14    1.0  1.0  Good
# 396         11    0.0  1.0   Bad
# 397         18    1.0  1.0   Bad
# 398         12    1.0  1.0   Bad
# 399         16    1.0  1.0  Good
#
# [400 rows x 11 columns]

# %%
x=df.iloc[:,0:10]
y=df.loc[:,'sales']
x
# Out:
#      CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age  \
# 0          138      73           11         276    120        0.0   42
# 1          111      48           16         260     83        1.0   65
# 2          113      35           10         269     80        2.0   59
# 3          117     100            4         466     97        2.0   55
# 4          141      64            3         340    128        0.0   38
# ..         ...     ...          ...         ...    ...        ...  ...
# 395        138     108           17         203    128        1.0   33
# 396        139      23            3          37    120        2.0   55
# 397        162      26           12         368    159        2.0   40
# 398        100      79            7         284     95        0.0   50
# 399        134      37            0          27    120        1.0   49
#
#      Education  Urban   US
# 0           17    1.0  1.0
# 1           10    1.0  1.0
# 2           12    1.0  1.0
# 3           14    1.0  1.0
# 4           13    1.0  0.0
# ..         ...    ...  ...
# 395         14    1.0  1.0
# 396         11    0.0  1.0
# 397         18    1.0  1.0
# 398         12    1.0  1.0
# 399         16    1.0  1.0
#
# [400 rows x 10 columns]

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,train_size=0.7,random_state=2)

# %%
dt=DecisionTreeClassifier()
dt.fit(xtrain,ytrain)
ypred=dt.predict(xtest)

# %%
print(classification_report(ytest,ypred))
# Out:
#               precision    recall  f1-score   support
#
#          Bad       0.73      0.64      0.68        64
#         Good       0.64      0.73      0.68        56
#
#     accuracy                           0.68       120
#    macro avg       0.69      0.69      0.68       120
# weighted avg       0.69      0.68      0.68       120

# %%
confusion_matrix(ytest,ypred)
# Out:
# array([[41, 23],
#        [15, 41]], dtype=int64)

# %%
dt.score(xtrain,ytrain),dt.score(xtest,ytest)
# Out:
# (1.0, 0.6833333333333333)

# %%
dt.feature_importances_
# Out:
# array([0.09158045, 0.06721155, 0.11814454, 0.14922516, 0.32660038,
#        0.04611513, 0.16560228, 0.01765517, 0.        , 0.01786535])

# %%
pd.DataFrame({'features':xtrain.columns,
              'IG':dt.feature_importances_
             }).sort_values(by='IG',ascending=False)
# Out:
#       features        IG
# 4        Price  0.326600
# 6          Age  0.165602
# 3   Population  0.149225
# 2  Advertising  0.118145
# 0    CompPrice  0.091580
# 1       Income  0.067212
# 5    ShelveLoc  0.046115
# 9           US  0.017865
# 7    Education  0.017655
# 8        Urban  0.000000

# %% [markdown]
# # Hyperparameter

# %%
params = {
    'criterion' : ['gini','entropy'],
    'splitter' : ['best','random'],
    'max_depth' : [2,3,4,6,9,12,16],
    'min_samples_split':[2,4,5,6,8,10]
    }

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid = GridSearchCV(DecisionTreeClassifier(), param_grid=params, verbose=-1)

# %%
grid.fit(xtrain,ytrain)
# Out:
# GridSearchCV(estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 3, 4, 6, 9, 12, 16],
#                          'min_samples_split': [2, 4, 5, 6, 8, 10],
#                          'splitter': ['best', 'random']},
#              verbose=-1)

# %%
grid.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 6,
#  'min_samples_split': 8,
#  'splitter': 'random'}

# %%
dt1=DecisionTreeClassifier(criterion='entropy',max_depth=9,splitter='random',min_samples_split=8)

# %%
dt1.fit(xtrain,ytrain)
ypred=dt1.predict(xtest)

# %%
print(classification_report(ytest,ypred))
# Out:
#               precision    recall  f1-score   support
#
#          Bad       0.75      0.69      0.72        64
#         Good       0.67      0.73      0.70        56
#
#     accuracy                           0.71       120
#    macro avg       0.71      0.71      0.71       120
# weighted avg       0.71      0.71      0.71       120

# %%
dt1.score(xtrain,ytrain),dt1.score(xtest,ytest)
# Out:
# (0.8714285714285714, 0.7083333333333334)

# %%
dt1.feature_importances_
# Out:
# array([0.12990928, 0.05314492, 0.10736721, 0.00987048, 0.36461609,
#        0.14286987, 0.12128727, 0.02274471, 0.03011174, 0.01807844])

# %%
pd.DataFrame({'features':xtrain.columns,
              'IG':dt1.feature_importances_
             }).sort_values(by='IG',ascending=False)
# Out:
#       features        IG
# 4        Price  0.364616
# 5    ShelveLoc  0.142870
# 0    CompPrice  0.129909
# 6          Age  0.121287
# 2  Advertising  0.107367
# 1       Income  0.053145
# 8        Urban  0.030112
# 7    Education  0.022745
# 9           US  0.018078
# 3   Population  0.009870

# %%
from sklearn import tree

# %%
tree.plot_tree(dt1,feature_names=x.columns, class_names=df['sales'].unique(), filled=True)
# Out:
# [Text(0.5925925925925926, 0.95, 'Advertising <= 11.613\nentropy = 1.0\nsamples = 280\nvalue = [137, 143]\nclass = Bad'),
#  Text(0.25, 0.85, 'ShelveLoc <= 0.826\nentropy = 0.992\nsamples = 208\nvalue = [115, 93]\nclass = Good'),
#  Text(0.07407407407407407, 0.75, 'Price <= 116.974\nentropy = 0.787\nsamples = 51\nvalue = [39, 12]\nclass = Good'),
#  Text(0.037037037037037035, 0.65, 'Price <= 85.5\nentropy = 0.961\nsamples = 26\nvalue = [16, 10]\nclass = Good'),
#  Text(0.018518518518518517, 0.55, 'entropy = 0.722\nsamples = 5\nvalue = [1, 4]\nclass = Bad'),
#  Text(0.05555555555555555, 0.55, 'Age <= 49.11\nentropy = 0.863\nsamples = 21\nvalue = [15, 6]\nclass = Good'),
#  Text(0.037037037037037035, 0.45, 'entropy = 0.985\nsamples = 7\nvalue = [3, 4]\nclass = Bad'),
#  Text(0.07407407407407407, 0.45, 'Income <= 97.456\nentropy = 0.592\nsamples = 14\nvalue = [12, 2]\nclass = Good'),
#  Text(0.05555555555555555, 0.35, 'entropy = 0.0\nsamples = 10\nvalue = [10, 0]\nclass = Good'),
#  Text(0.09259259259259259, 0.35, 'entropy = 1.0\nsamples = 4\nvalue = [2, 2]\nclass = Good'),
#  Text(0.1111111111111111, 0.65, 'Advertising <= 2.265\nentropy = 0.402\nsamples = 25\nvalue = [23, 2]\nclass = Good'),
#  Text(0.09259259259259259, 0.55, 'entropy = 0.0\nsamples = 12\nvalue = [12, 0]\nclass = Good'),
#  Text(0.12962962962962962, 0.55, 'Education <= 13.819\nentropy = 0.619\nsamples = 13\nvalue = [11, 2]\nclass = Good'),
#  Text(0.1111111111111111, 0.45, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = Good'),
#  Text(0.14814814814814814, 0.45, 'Education <= 16.475\nentropy = 0.811\nsamples = 8\nvalue = [6, 2]\nclass = Good'),
#  Text(0.12962962962962962, 0.35, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Good'),
#  Text(0.16666666666666666, 0.35, 'entropy = 1.0\nsamples = 4\nvalue = [2, 2]\nclass = Good'),
#  Text(0.42592592592592593, 0.75, 'ShelveLoc <= 1.382\nentropy = 0.999\nsamples = 157\nvalue = [76, 81]\nclass = Bad'),
#  Text(0.3055555555555556, 0.65, 'US <= 0.015\nentropy = 0.693\nsamples = 43\nvalue = [8, 35]\nclass = Bad'),
#  Text(0.25925925925925924, 0.55, 'Price <= 125.182\nentropy = 0.918\nsamples = 18\nvalue = [6, 12]\nclass = Bad'),
#  Text(0.2222222222222222, 0.45, 'CompPrice <= 99.193\nentropy = 0.503\nsamples = 9\nvalue = [1, 8]\nclass = Bad'),
#  Text(0.2037037037037037, 0.35, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = Good'),
#  Text(0.24074074074074073, 0.35, 'entropy = 0.0\nsamples = 7\nvalue = [0, 7]\nclass = Bad'),
#  Text(0.2962962962962963, 0.45, 'Income <= 61.627\nentropy = 0.991\nsamples = 9\nvalue = [5, 4]\nclass = Good'),
#  Text(0.2777777777777778, 0.35, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Good'),
#  Text(0.3148148148148148, 0.35, 'entropy = 0.918\nsamples = 6\nvalue = [2, 4]\nclass = Bad'),
#  Text(0.35185185185185186, 0.55, 'Urban <= 0.375\nentropy = 0.402\nsamples = 25\nvalue = [2, 23]\nclass = Bad'),
#  Text(0.3333333333333333, 0.45, 'entropy = 0.0\nsamples = 12\nvalue = [0, 12]\nclass = Bad'),
#  Text(0.37037037037037035, 0.45, 'Price <= 167.039\nentropy = 0.619\nsamples = 13\nvalue = [2, 11]\nclass = Bad'),
#  Text(0.35185185185185186, 0.35, 'CompPrice <= 134.845\nentropy = 0.414\nsamples = 12\nvalue = [1, 11]\nclass = Bad'),
#  Text(0.3333333333333333, 0.25, 'entropy = 0.592\nsamples = 7\nvalue = [1, 6]\nclass = Bad'),
#  Text(0.37037037037037035, 0.25, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = Bad'),
#  Text(0.3888888888888889, 0.35, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Good'),
#  Text(0.5462962962962963, 0.65, 'Price <= 116.497\nentropy = 0.973\nsamples = 114\nvalue = [68, 46]\nclass = Good'),
#  Text(0.4444444444444444, 0.55, 'Price <= 70.711\nentropy = 0.998\nsamples = 59\nvalue = [28, 31]\nclass = Bad'),
#  Text(0.42592592592592593, 0.45, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = Bad'),
#  Text(0.46296296296296297, 0.45, 'CompPrice <= 128.748\nentropy = 0.998\nsamples = 53\nvalue = [28, 25]\nclass = Good'),
#  Text(0.42592592592592593, 0.35, 'Price <= 73.327\nentropy = 0.926\nsamples = 41\nvalue = [27, 14]\nclass = Good'),
#  Text(0.4074074074074074, 0.25, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Bad'),
#  Text(0.4444444444444444, 0.25, 'Price <= 89.635\nentropy = 0.89\nsamples = 39\nvalue = [27, 12]\nclass = Good'),
#  Text(0.42592592592592593, 0.15, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Bad'),
#  Text(0.46296296296296297, 0.15, 'CompPrice <= 122.32\nentropy = 0.842\nsamples = 37\nvalue = [27, 10]\nclass = Good'),
#  Text(0.4444444444444444, 0.05, 'entropy = 0.709\nsamples = 31\nvalue = [25, 6]\nclass = Good'),
#  Text(0.48148148148148145, 0.05, 'entropy = 0.918\nsamples = 6\nvalue = [2, 4]\nclass = Bad'),
#  Text(0.5, 0.35, 'Urban <= 0.006\nentropy = 0.414\nsamples = 12\nvalue = [1, 11]\nclass = Bad'),
#  Text(0.48148148148148145, 0.25, 'entropy = 0.811\nsamples = 4\nvalue = [1, 3]\nclass = Bad'),
#  Text(0.5185185185185185, 0.25, 'entropy = 0.0\nsamples = 8\nvalue = [0, 8]\nclass = Bad'),
#  Text(0.6481481481481481, 0.55, 'Age <= 41.508\nentropy = 0.845\nsamples = 55\nvalue = [40, 15]\nclass = Good'),
#  Text(0.5925925925925926, 0.45, 'Advertising <= 10.251\nentropy = 0.996\nsamples = 13\nvalue = [7, 6]\nclass = Good'),
#  Text(0.5740740740740741, 0.35, 'CompPrice <= 128.91\nentropy = 0.98\nsamples = 12\nvalue = [7, 5]\nclass = Good'),
#  Text(0.5555555555555556, 0.25, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Good'),
#  Text(0.5925925925925926, 0.25, 'Age <= 33.841\nentropy = 1.0\nsamples = 10\nvalue = [5, 5]\nclass = Good'),
#  Text(0.5740740740740741, 0.15, 'entropy = 0.722\nsamples = 5\nvalue = [1, 4]\nclass = Bad'),
#  Text(0.6111111111111112, 0.15, 'entropy = 0.722\nsamples = 5\nvalue = [4, 1]\nclass = Good'),
#  Text(0.6111111111111112, 0.35, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Bad'),
#  Text(0.7037037037037037, 0.45, 'Advertising <= 3.374\nentropy = 0.75\nsamples = 42\nvalue = [33, 9]\nclass = Good'),
#  Text(0.6481481481481481, 0.35, 'Age <= 46.315\nentropy = 0.516\nsamples = 26\nvalue = [23, 3]\nclass = Good'),
#  Text(0.6296296296296297, 0.25, 'entropy = 0.971\nsamples = 5\nvalue = [3, 2]\nclass = Good'),
#  Text(0.6666666666666666, 0.25, 'CompPrice <= 136.508\nentropy = 0.276\nsamples = 21\nvalue = [20, 1]\nclass = Good'),
#  Text(0.6481481481481481, 0.15, 'entropy = 0.0\nsamples = 15\nvalue = [15, 0]\nclass = Good'),
#  Text(0.6851851851851852, 0.15, 'entropy = 0.65\nsamples = 6\nvalue = [5, 1]\nclass = Good'),
#  Text(0.7592592592592593, 0.35, 'Age <= 64.921\nentropy = 0.954\nsamples = 16\nvalue = [10, 6]\nclass = Good'),
#  Text(0.7407407407407407, 0.25, 'Price <= 118.123\nentropy = 0.863\nsamples = 14\nvalue = [10, 4]\nclass = Good'),
#  Text(0.7222222222222222, 0.15, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Bad'),
#  Text(0.7592592592592593, 0.15, 'Population <= 247.393\nentropy = 0.65\nsamples = 12\nvalue = [10, 2]\nclass = Good'),
#  Text(0.7407407407407407, 0.05, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = Good'),
#  Text(0.7777777777777778, 0.05, 'entropy = 0.863\nsamples = 7\nvalue = [5, 2]\nclass = Good'),
#  Text(0.7777777777777778, 0.25, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Bad'),
#  Text(0.9351851851851852, 0.85, 'Price <= 144.899\nentropy = 0.888\nsamples = 72\nvalue = [22, 50]\nclass = Bad'),
#  Text(0.9166666666666666, 0.75, 'Price <= 129.557\nentropy = 0.758\nsamples = 64\nvalue = [14, 50]\nclass = Bad'),
#  Text(0.8703703703703703, 0.65, 'Age <= 52.968\nentropy = 0.598\nsamples = 55\nvalue = [8, 47]\nclass = Bad'),
#  Text(0.8333333333333334, 0.55, 'Urban <= 0.458\nentropy = 0.229\nsamples = 27\nvalue = [1, 26]\nclass = Bad'),
#  Text(0.8148148148148148, 0.45, 'Income <= 90.412\nentropy = 0.503\nsamples = 9\nvalue = [1, 8]\nclass = Bad'),
#  Text(0.7962962962962963, 0.35, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = Bad'),
#  Text(0.8333333333333334, 0.35, 'entropy = 0.918\nsamples = 3\nvalue = [1, 2]\nclass = Bad'),
#  Text(0.8518518518518519, 0.45, 'entropy = 0.0\nsamples = 18\nvalue = [0, 18]\nclass = Bad'),
#  Text(0.9074074074074074, 0.55, 'CompPrice <= 109.182\nentropy = 0.811\nsamples = 28\nvalue = [7, 21]\nclass = Bad'),
#  Text(0.8888888888888888, 0.45, 'entropy = 0.971\nsamples = 5\nvalue = [3, 2]\nclass = Good'),
#  Text(0.9259259259259259, 0.45, 'Age <= 73.553\nentropy = 0.667\nsamples = 23\nvalue = [4, 19]\nclass = Bad'),
#  Text(0.9074074074074074, 0.35, 'Advertising <= 17.569\nentropy = 0.323\nsamples = 17\nvalue = [1, 16]\nclass = Bad'),
#  Text(0.8888888888888888, 0.25, 'entropy = 0.0\nsamples = 15\nvalue = [0, 15]\nclass = Bad'),
#  Text(0.9259259259259259, 0.25, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = Good'),
#  Text(0.9444444444444444, 0.35, 'entropy = 1.0\nsamples = 6\nvalue = [3, 3]\nclass = Good'),
#  Text(0.9629629629629629, 0.65, 'Price <= 134.364\nentropy = 0.918\nsamples = 9\nvalue = [6, 3]\nclass = Good'),
#  Text(0.9444444444444444, 0.55, 'entropy = 0.811\nsamples = 4\nvalue = [1, 3]\nclass = Bad'),
#  Text(0.9814814814814815, 0.55, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = Good'),
#  Text(0.9537037037037037, 0.75, 'entropy = 0.0\nsamples = 8\nvalue = [8, 0]\nclass = Good')]
